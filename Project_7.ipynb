# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span><ul class="toc-item"><li><span><a href="#Подключение-библиотек" data-toc-modified-id="Подключение-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Подключение библиотек</a></span></li><li><span><a href="#Загрузка-данных-из-таблиц" data-toc-modified-id="Загрузка-данных-из-таблиц-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных из таблиц</a></span></li><li><span><a href="#Функция-для-первичного-анализа" data-toc-modified-id="Функция-для-первичного-анализа-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Функция для первичного анализа</a></span></li><li><span><a href="#Таблица-visits" data-toc-modified-id="Таблица-visits-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Таблица <code>visits</code></a></span><ul class="toc-item"><li><span><a href="#Изучение-таблицы" data-toc-modified-id="Изучение-таблицы-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Изучение таблицы</a></span></li><li><span><a href="#Оптимизация-данных-в-таблице" data-toc-modified-id="Оптимизация-данных-в-таблице-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Оптимизация данных в таблице</a></span></li></ul></li><li><span><a href="#Таблица-orders" data-toc-modified-id="Таблица-orders-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Таблица <code>orders</code></a></span><ul class="toc-item"><li><span><a href="#Изучение-таблицы" data-toc-modified-id="Изучение-таблицы-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Изучение таблицы</a></span></li><li><span><a href="#Оптимизация-данных" data-toc-modified-id="Оптимизация-данных-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Оптимизация данных</a></span></li></ul></li><li><span><a href="#Таблица-costs" data-toc-modified-id="Таблица-costs-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Таблица <code>costs</code></a></span><ul class="toc-item"><li><span><a href="#Изучение-таблицы" data-toc-modified-id="Изучение-таблицы-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Изучение таблицы</a></span></li><li><span><a href="#Оптимизация-данных" data-toc-modified-id="Оптимизация-данных-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Оптимизация данных</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчета-удержания" data-toc-modified-id="Функция-для-расчета-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчета удержания</a></span></li><li><span><a href="#Функция-для-расчета-конверсии" data-toc-modified-id="Функция-для-расчета-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчета конверсии</a></span></li><li><span><a href="#Функция-для-расчета-LTV-и-ROI" data-toc-modified-id="Функция-для-расчета-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчета <code>LTV</code> и <code>ROI</code></a></span></li><li><span><a href="#Функция-для-сглаживания" data-toc-modified-id="Функция-для-сглаживания-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации <code>LTV</code> и <code>ROI</code></a></span></li></ul></li><li><span><a href="#Проведите-исследовательский-анализ-данных" data-toc-modified-id="Проведите-исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили" data-toc-modified-id="Профили-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили</a></span><ul class="toc-item"><li><span><a href="#Получение-пользовательских-профилей" data-toc-modified-id="Получение-пользовательских-профилей-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Получение пользовательских профилей</a></span></li><li><span><a href="#Определение-минимальной-и-максимальной-даты-привлечения" data-toc-modified-id="Определение-минимальной-и-максимальной-даты-привлечения-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Определение минимальной и максимальной даты привлечения</a></span></li></ul></li><li><span><a href="#Анализ-профилей-по-группам" data-toc-modified-id="Анализ-профилей-по-группам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ профилей по группам</a></span><ul class="toc-item"><li><span><a href="#Функция-для-группировки-профилей" data-toc-modified-id="Функция-для-группировки-профилей-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Функция для группировки профилей</a></span></li><li><span><a href="#Группировка-по-региону" data-toc-modified-id="Группировка-по-региону-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Группировка по региону</a></span></li><li><span><a href="#Группировка-по-девайсу" data-toc-modified-id="Группировка-по-девайсу-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Группировка по девайсу</a></span></li><li><span><a href="#Группировка-по-каналу-привлечения" data-toc-modified-id="Группировка-по-каналу-привлечения-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Группировка по каналу привлечения</a></span></li><li><span><a href="#Группировка-по-каналу-привлечения-и-региону" data-toc-modified-id="Группировка-по-каналу-привлечения-и-региону-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Группировка по каналу привлечения и региону</a></span></li><li><span><a href="#Группировка-по-каналу-привлечения-и-устройству" data-toc-modified-id="Группировка-по-каналу-привлечения-и-устройству-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Группировка по каналу привлечения и устройству</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Суммарные-расходы-на-рекламу" data-toc-modified-id="Суммарные-расходы-на-рекламу-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Суммарные расходы на рекламу</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов" data-toc-modified-id="Общая-сумма-расходов-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Общая сумма расходов</a></span></li><li><span><a href="#Разбивка-расходов-по-канал-привлечения" data-toc-modified-id="Разбивка-расходов-по-канал-привлечения-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Разбивка расходов по канал привлечения</a></span></li><li><span><a href="#Динамика-расходов-по-каналам" data-toc-modified-id="Динамика-расходов-по-каналам-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Динамика расходов по каналам</a></span></li></ul></li><li><span><a href="#Стоимость-привлечения-покупателя" data-toc-modified-id="Стоимость-привлечения-покупателя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Стоимость привлечения покупателя</a></span><ul class="toc-item"><li><span><a href="#Средняя-стоимость-привлечения-покупателя" data-toc-modified-id="Средняя-стоимость-привлечения-покупателя-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Средняя стоимость привлечения покупателя</a></span></li><li><span><a href="#Средняя-стоимость-привлечения-с-разбивкой-по-каналам" data-toc-modified-id="Средняя-стоимость-привлечения-с-разбивкой-по-каналам-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Средняя стоимость привлечения с разбивкой по каналам</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оцените-окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оцените-окупаемость-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оцените окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Формирование-выборки-для-исследования" data-toc-modified-id="Формирование-выборки-для-исследования-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Формирование выборки для исследования</a></span></li><li><span><a href="#Момент-и-горизонт-анализа" data-toc-modified-id="Момент-и-горизонт-анализа-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Момент и горизонт анализа</a></span></li><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span><ul class="toc-item"><li><span><a href="#Получаем-таблицы-LTV-и-ROI,-а-так-же-визуализируем-их" data-toc-modified-id="Получаем-таблицы-LTV-и-ROI,-а-так-же-визуализируем-их-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Получаем таблицы <code>LTV</code> и <code>ROI</code>, а так же визуализируем их</a></span></li><li><span><a href="#Получаем-таблицы-конверсии-и-визуализацию" data-toc-modified-id="Получаем-таблицы-конверсии-и-визуализацию-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Получаем таблицы конверсии и визуализацию</a></span></li><li><span><a href="#Получаем-таблицы-удержания-и-визуализацию" data-toc-modified-id="Получаем-таблицы-удержания-и-визуализацию-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Получаем таблицы удержания и визуализацию</a></span></li></ul></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span><ul class="toc-item"><li><span><a href="#Таблицы-LTV-и-ROI,-а-так-же-визуализация" data-toc-modified-id="Таблицы-LTV-и-ROI,-а-так-же-визуализация-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Таблицы <code>LTV</code> и <code>ROI</code>, а так же визуализация</a></span></li><li><span><a href="#Таблицы-конверсии-и-визуализация" data-toc-modified-id="Таблицы-конверсии-и-визуализация-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Таблицы конверсии и визуализация</a></span></li><li><span><a href="#Таблицы-удержания-и-визуализация" data-toc-modified-id="Таблицы-удержания-и-визуализация-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Таблицы удержания и визуализация</a></span></li></ul></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Таблицы-LTV-и-ROI,-а-так-же-визуализация" data-toc-modified-id="Таблицы-LTV-и-ROI,-а-так-же-визуализация-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Таблицы <code>LTV</code> и <code>ROI</code>, а так же визуализация</a></span></li><li><span><a href="#Таблицы-конверсии-и-визуализация" data-toc-modified-id="Таблицы-конверсии-и-визуализация-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>Таблицы конверсии и визуализация</a></span></li><li><span><a href="#Таблицы-удержания-и-визуализация" data-toc-modified-id="Таблицы-удержания-и-визуализация-5.6.3"><span class="toc-item-num">5.6.3&nbsp;&nbsp;</span>Таблицы удержания и визуализация</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# **Описание данных**
#
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
# * User Id — уникальный идентификатор пользователя
# * Device — категория устройства пользователя
# * Session start — дата и время начала сессии
# * Session End — дата и время окончания сессии
# * Channel — идентификатор рекламного источника, из которого пришел пользователь
# * Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
# * User Id — уникальный id пользователя, который сделал заказ
# * Event Dt — дата и время покупки
# * Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
# * Channel — идентификатор рекламного источника
# * Dt — дата
# * Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Загрузка данных и подготовка к анализу

# %% [markdown]
# ### Подключение библиотек

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Загрузка данных из таблиц

# %%
try: 
    visits = pd.read_csv('visits_info_short.csv')
    orders = pd.read_csv('orders_info_short.csv')
    costs = pd.read_csv('costs_info_short.csv')
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# ### Функция для первичного анализа

# %%
def data_info(data):
    data.columns = [x.lower().replace(' ', '_') for x in data.columns.values]
    display(data.info())
    display(data.head())
    display(data.describe())

# %% [markdown]
# ### Таблица `visits`

# %% [markdown]
# #### Изучение таблицы

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
data_info(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
# ...

# %% [markdown]
# #### Оптимизация данных в таблице

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
display(visits.duplicated().sum())
display(visits['region'].unique())
display(visits['device'].unique())
visits['channel'].unique()
# Out:
# 0
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# ### Таблица `orders`

# %% [markdown]
# #### Изучение таблицы

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
data_info(orders)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#             user_id       revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000

# %% [markdown]
# #### Оптимизация данных

# %%
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Таблица `costs`

# %% [markdown]
# #### Изучение таблицы

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
data_info(costs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
#              costs
# count  1800.000000
# mean     58.609611
# std     107.740223
# min       0.800000
# 25%       6.495000
# 50%      12.285000
# 75%      33.600000
# max     630.000000

# %% [markdown]
# #### Оптимизация данных

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
display(costs.duplicated().sum())
display(costs['channel'].unique())
costs.head()
# Out:
# 0
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# ### Вывод

# %% [markdown]
# Познакомившись со всеми предоставленными данными, я привела таблицы к правильному виду, проверила их на дубликаты, а так же поменяла тип данных с `object` на `datetime` во всех столбцах с датами.

# %% [markdown]
# ## Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, events, ad_costs, event_names=[]):
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчета удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета `LTV` и `ROI`

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )
        roi = result.div(cac['cac'], axis=0)
        roi = roi[~roi['cohort_size'].isin([np.inf])]
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )
    if 'cohort' in dimensions:
        dimensions = []
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в четвёртой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации `LTV` и `ROI`

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    plt.figure(figsize=(16, 10))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]
    cac_history = roi_history[['cac']]
    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ### Профили

# %% [markdown]
# #### Получение пользовательских профилей

# %%
events = None
users = get_profiles(visits, orders, events, costs)
users.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# #### Определение минимальной и максимальной даты привлечения

# %%
print('Минимальная дата привлечения пользователей', users['first_ts'].min(), end='\n')
print('Максимальная дата привлечения пользователей', users['first_ts'].max(), end='\n')
# Out:
# Минимальная дата привлечения пользователей 2019-05-01 00:00:41
# Максимальная дата привлечения пользователей 2019-10-27 23:59:04

# %% [markdown]
# ### Анализ профилей по группам

# %% [markdown]
# #### Функция для группировки профилей

# %%
def grouped_table(data, index):
    grouped_data = (data
                   .pivot_table(index=index, 
                                columns='payer', 
                                values='user_id', 
                                aggfunc='nunique')
                   .reset_index())
    grouped_data.columns = [index, 'not_payer', 'payer']
    grouped_data['pers'] = round((grouped_data['payer'] / (grouped_data['not_payer']+grouped_data['payer']) * 100), 2)
    grouped_data = grouped_data.sort_values(by='pers', ascending=False).reset_index(drop=True)
    return grouped_data

# %% [markdown]
# #### Группировка по региону

# %%
regions_grouped = grouped_table(users, 'region')
regions_grouped
# Out:
#           region  not_payer  payer  pers
# 0  United States      93100   6902  6.90
# 1        Germany      14365    616  4.11
# 2             UK      16875    700  3.98
# 3         France      16787    663  3.80

# %% [markdown]
# #### Группировка по девайсу

# %%
devices_grouped = grouped_table(users, 'device')
devices_grouped
# Out:
#     device  not_payer  payer  pers
# 0      Mac      28130   1912  6.36
# 1   iPhone      51097   3382  6.21
# 2  Android      32982   2050  5.85
# 3       PC      28918   1537  5.05

# %% [markdown]
# #### Группировка по каналу привлечения

# %%
channels_grouped = grouped_table(users, 'channel')
channels_grouped
# Out:
#                channel  not_payer  payer   pers
# 0             FaceBoom      25587   3557  12.20
# 1           AdNonSense       3440    440  11.34
# 2       lambdaMediaAds       1924    225  10.47
# 3               TipTop      17683   1878   9.60
# 4       RocketSuperAds       4096    352   7.91
# 5       WahooNetBanner       8100    453   5.30
# 6              YRabbit       4147    165   3.83
# 7         MediaTornado       4208    156   3.57
# 8              LeapBob       8291    262   3.06
# 9   OppleCreativeMedia       8372    233   2.71
# 10             organic      55279   1160   2.06

# %% [markdown]
# #### Группировка по каналу привлечения и региону

# %%
group_channel_reg = (users
         .pivot_table(index=['channel', 'region'], 
                      columns='payer', 
                      values='user_id', 
                      aggfunc='nunique')
         .reset_index()
        )
group_channel_reg.columns = ['channel','region', 'not_payer', 'payer']
group_channel_reg['pers'] = round((group_channel_reg['payer'] / 
                                   (group_channel_reg['not_payer']+
                                    group_channel_reg['payer']) * 
                                   100), 2)
group_channel_reg = group_channel_reg.sort_values(by='pers', ascending=False).reset_index(drop=True)
group_channel_reg.head(10)
# Out:
#           channel         region  not_payer  payer   pers
# 0        FaceBoom  United States      25587   3557  12.20
# 1      AdNonSense        Germany       1077    142  11.65
# 2      AdNonSense             UK       1147    148  11.43
# 3  lambdaMediaAds         France        660     82  11.05
# 4      AdNonSense         France       1216    150  10.98
# 5  lambdaMediaAds        Germany        582     67  10.32
# 6  lambdaMediaAds             UK        682     76  10.03
# 7          TipTop  United States      17683   1878   9.60
# 8  RocketSuperAds  United States       4096    352   7.91
# 9  WahooNetBanner        Germany       2431    148   5.74

# %% [markdown]
# #### Группировка по каналу привлечения и устройству

# %%
group_channel_dev = (users
                     .pivot_table(index=['channel', 'device'], 
                                  columns='payer', 
                                  values='user_id', 
                                  aggfunc='nunique')
                     .reset_index()
                    )
group_channel_dev.columns = ['channel','device', 'not_payer', 'payer']
group_channel_dev['pers'] = round((group_channel_dev['payer'] / 
                                   (group_channel_dev['not_payer'] + 
                                    group_channel_dev['payer']) * 
                                   100), 2)
group_channel_dev = group_channel_dev.sort_values(by='pers', ascending=False).reset_index(drop=True)
group_channel_dev.head(10)
# Out:
#           channel   device  not_payer  payer   pers
# 0        FaceBoom  Android       5091    784  13.34
# 1  lambdaMediaAds   iPhone        378     55  12.70
# 2      AdNonSense       PC       1371    192  12.28
# 3        FaceBoom      Mac       6379    886  12.20
# 4        FaceBoom       PC       2651    357  11.87
# 5        FaceBoom   iPhone      11466   1530  11.77
# 6      AdNonSense   iPhone        707     91  11.40
# 7  lambdaMediaAds      Mac        215     26  10.79
# 8      AdNonSense  Android        991    118  10.64
# 9          TipTop  Android       3480    409  10.52

# %% [markdown]
# ### Вывод

# %% [markdown]
# Анализ пользовательских профилей показал:
# * минимальная дата привлечения - **01.05.2019**
# * максимальная дата привлечения - **27.10.2019**
# * наибольший процент платящих пользователей проживают в **США**, в полтора раза больше (*6,9%*), чем в Германии (*4,11%*) и Великобритании (*3,98%*)
# * доли покупателей среди пользующихся устройствами **Mac** (*6,36%*) и **iPhone** (*6,21%*) примерно одинаковы, доли Android (*5,85%*) и PC (*5,05%*) немного меньше
# * рекламные площадки **FaceBoom** (*12,2%*), **AdNonSense** (*11,34%*), **lambdaMediaAds** (*10,47%*) и **TipTop** (*9,6%*) привлекают больше платящих клиентов, чем остальные рекламные источники

# %% [markdown]
# ## Маркетинг
#
# Выясните:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# ### Суммарные расходы на рекламу

# %% [markdown]
# #### Общая сумма расходов

# %%
total_cost = costs['costs'].sum()
total_cost
# Out:
# 105497.30000000002

# %% [markdown]
# #### Разбивка расходов по канал привлечения

# %%
channel_cost = (costs
                .pivot_table(index='channel',
                             values='costs',
                             aggfunc='sum')
                .reset_index()
                .sort_values(by='costs', ascending=False)
)
channel_cost['pers'] = round((channel_cost['costs'] / total_cost * 100), 2)
display(channel_cost)
plt.figure(figsize = (20, 10))
sns.set_theme(style='darkgrid')
sns.barplot(x='channel', y='costs', data=channel_cost, color='cyan', saturation=.4)
plt.title('Суммарные расходы по источникам', fontsize=20)
plt.xlabel('Источники', fontsize=15)
plt.ylabel('Суммарные расходы', fontsize=15)
plt.xticks(rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()
# Out:
#               channel     costs   pers
# 6              TipTop  54751.30  51.90
# 1            FaceBoom  32445.60  30.75
# 7      WahooNetBanner   5151.00   4.88
# 0          AdNonSense   3911.25   3.71
# 4  OppleCreativeMedia   2151.25   2.04
# 5      RocketSuperAds   1833.00   1.74
# 2             LeapBob   1797.60   1.70
# 9      lambdaMediaAds   1557.60   1.48
# 3        MediaTornado    954.48   0.90
# 8             YRabbit    944.22   0.90

# %% [markdown]
# #### Динамика расходов по каналам

# %%
costs.pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum').plot(grid=True, figsize = (20, 10))
plt.title('Динамика расходов по источникам', fontsize=20)
plt.xlabel('Даты проведения кампании', fontsize=15)
plt.ylabel('Суммарные расходы', fontsize=15)
plt.show()

# %%
(costs
 .query('channel in ["FaceBoom", "TipTop"]')
 .pivot_table(index='dt', 
              columns='channel', 
              values='costs', 
              aggfunc='sum')
 .plot(grid=True, figsize = (20, 10))
)
plt.title('Динамика расходов крупнейших источников', fontsize=20)
plt.xlabel('Даты проведения кампании', fontsize=15)
plt.ylabel('Суммарные расходы', fontsize=15)
plt.show()

# %%
(costs
 .query('channel not in ["FaceBoom", "TipTop"]')
 .pivot_table(index='dt', 
              columns='channel', 
              values='costs', 
              aggfunc='sum')
 .plot(grid=True, figsize = (20, 10))
)
plt.title('Динамика расходов остальных источников', fontsize=20)
plt.xlabel('Даты проведения кампании', fontsize=15)
plt.ylabel('Суммарные расходы', fontsize=15)
plt.show()

# %% [markdown]
# ### Стоимость привлечения покупателя

# %% [markdown]
# #### Средняя стоимость привлечения покупателя

# %%
mean_cac = round((users['acquisition_cost'].mean()),2)
mean_cac
# Out:
# 0.7

# %% [markdown]
# #### Средняя стоимость привлечения с разбивкой по каналам

# %%
cac_channel = (users
               .pivot_table(index='channel', 
                            values='acquisition_cost', 
                            aggfunc='mean')
               .sort_values(by='acquisition_cost', ascending=False)
               .reset_index()
              )
display(cac_channel)
plt.figure(figsize = (20, 10))
sns.set_theme(style='darkgrid')
sns.barplot(x='channel', y='acquisition_cost', data=cac_channel, color="salmon", saturation=.5)
plt.title('Средняя стоимость привлечения пользователя', fontsize=20)
plt.xlabel('Источники', fontsize=15)
plt.ylabel('Средняя стоимость', fontsize=15)
plt.xticks(rotation=45, fontsize=16)
plt.yticks(fontsize=16)
plt.show()
# Out:
#                channel  acquisition_cost
# 0               TipTop          2.799003
# 1             FaceBoom          1.113286
# 2           AdNonSense          1.008054
# 3       lambdaMediaAds          0.724802
# 4       WahooNetBanner          0.602245
# 5       RocketSuperAds          0.412095
# 6   OppleCreativeMedia          0.250000
# 7              YRabbit          0.218975
# 8         MediaTornado          0.218717
# 9              LeapBob          0.210172
# 10             organic          0.000000

# %% [markdown]
# ### Вывод

# %% [markdown]
# На рекламную площадку **TipTop** тратится больше половины рекламного бюджета, хотя средняя стоимость привлечения пользователя на этой площадке в 4 раза превышает среднюю стоимость привлечения по всем рекламным каналам.
#
# Так же ранее мы увидели, что рекламные площадки *FaceBoom*, *AdNonSense* и *lambdaMediaAds* привлекают бОльший процент платящих пользователей.

# %% [markdown]
# ## Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Формирование выборки для исследования

# %%
users_analysis = users.query('channel != "organic"')

# %% [markdown]
# ### Момент и горизонт анализа

# %%
observation_date = datetime(2019,11,1).date()
horizon_days = 14

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %%
ltw_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    users_analysis, orders, observation_date, horizon_days
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# #### Получаем таблицы `LTV` и `ROI`, а так же визуализируем их

# %%
dimensions = ['device']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    users_analysis, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# #### Получаем таблицы конверсии и визуализацию

# %%
conv_raw, conv, conv_history = get_conversion(
    users_analysis, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_conversion(conv, conv_history, horizon_days, window=14)

# %% [markdown]
# #### Получаем таблицы удержания и визуализацию

# %%
retention_raw, retention, retention_history = get_retention(
    users_analysis, visits, observation_date, horizon_days, dimensions=dimensions
)
plot_retention(retention, retention_history, horizon_days, window=14)

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# #### Таблицы `LTV` и `ROI`, а так же визуализация

# %%
dimensions = ['region']
ltw_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    users_analysis, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# #### Таблицы конверсии и визуализация

# %%
conv_raw, conv, conv_history = get_conversion(
    users_analysis, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_conversion(conv, conv_history, horizon_days, window=14)

# %% [markdown]
# #### Таблицы удержания и визуализация

# %%
retention_raw, retention, retention_history = get_retention(
    users_analysis, visits, observation_date, horizon_days, dimensions=dimensions
)
plot_retention(retention, retention_history, horizon_days, window=14)

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# #### Таблицы `LTV` и `ROI`, а так же визуализация

# %%
dimensions = ['channel']
ltw_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    users_analysis, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# #### Таблицы конверсии и визуализация

# %%
conv_raw, conv, conv_history = get_conversion(
    users_analysis, orders, observation_date, horizon_days, dimensions=dimensions
)
plot_conversion(conv, conv_history, horizon_days, window=14)

# %% [markdown]
# #### Таблицы удержания и визуализация

# %%
retention_raw, retention, retention_history = get_retention(
    users_analysis, visits, observation_date, horizon_days, dimensions=dimensions
)
plot_retention(retention, retention_history, horizon_days, window=14)

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Реклама, направленная на привлечение пользователей, в целом **не окупается**
# 2. Устройства, страны и рекламные каналы, возможно оказывающие негативное влияние на окупаемость рекламы:
#     * пользователи устройств Mac, iPhone и Android не оккупаются, не смотря на высокую конверсию
#     * клиенты из США стабильно не окупаются, они имеют высокую конверсию, но существенно меньшее удержание
#     * рекламные площадки *FaceBoom*, *AdNonSense* и *TipTop* стабильно не окупаются. *TipTop* имеет высокую конверсию и удержание, но за счет увеличивающейся стоимости привлечения, не достигает уровня окупаемости, а *FaceBoom* и *AdNonSense* имеют очень низкое удержание пользователей

# %% [markdown]
# ## Выводы

# %% [markdown]
# * Рекламный бюджет распределяется не равномерно, бОльшая часть уходит на рекламные площадки, которые не приносят окупаемых пользователей, но при этом имеют высокую и растущую стоимость привлечения пользователя.
#
# * Упор направлен на американский сегмент, в то время как европейские пользователи показывают стабильную окупаемость и стоимость привлечения.
#
# * Стоит обратить внимание на пользователей PC, они показывают стабильную окупаемость и удержание.
